# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('./input/youtube_trending_mediterranean.csv')
df.head()
# Out:
#   country     video_id                                              title  \
# 0      AL  hxWSp-8jJuo                                 DON XHONI - KATILE
# 1      AL  MnrC9mk2H1o  Dhurata Dora x Elvana Gjata - GAJDE (Official ...
# 2      AL  5Ql-G0dTqC0                       KIDA x BUTRINT IMERI - AM/PM
# 3      AL  oUdY0qSavvY                              Dafina Zeqiri - Malli
# 4      AL  I4ZSvYLnOcQ                             Tayna x Azet - Tequila
#
#             publishedAt                 channelId           channelTitle  \
# 0  2022-07-07T22:00:12Z  UCZNJXsf2I4y54M_UmMiC6Vw              DON XHONI
# 1  2022-06-30T22:00:11Z  UCtzhq8TIfFB9vRAHVqLL9PA           Dhurata Dora
# 2  2022-07-02T22:00:11Z  UCAHVxL9FG3Sp8ltQtLEy_oA                   KIDA
# 3  2022-07-07T22:00:12Z  UCrv0PJoutcRhHkSMJYoXAIQ          Dafina Zeqiri
# 4  2022-06-30T18:00:26Z  UCJBZ-GcWSswmJ0xc9WAKDqw  Friends Entertainment
#
#    categoryId trending_date  \
# 0          24      22.11.07
# 1          10      22.11.07
# 2          10      22.11.07
# 3          10      22.11.07
# 4          10      22.11.07
#
#                                                 tags  view_count  \
# 0                                             [none]     5130167
# 1                                             [none]     8886648
# 2  Butrint Imeri|Kida|Dale|Butrint imeri kida|But...     7230818
# 3  Dafina|Zeqiri|Dafine Moj|Pa ty|Lule Lule|Duro|...     1406078
# 4  tayna|Friends|Entertainment|rinor hykolli|hip ...     6397676
#
#    comment_count                                  thumbnail_link  \
# 0           3641  https://i.ytimg.com/vi/hxWSp-8jJuo/default.jpg
# 1           4414  https://i.ytimg.com/vi/MnrC9mk2H1o/default.jpg
# 2           7518  https://i.ytimg.com/vi/5Ql-G0dTqC0/default.jpg
# 3            827  https://i.ytimg.com/vi/oUdY0qSavvY/default.jpg
# 4           6063  https://i.ytimg.com/vi/I4ZSvYLnOcQ/default.jpg
#
#    comments_disabled  ratings_disabled  \
# 0              False              True
# 1              False              True
# 2              False              True
# 3              False              True
# 4              False              True
#
#                                          description
# 0  Stream or Download now ''KATILE'' ð https:/...
# 1  The official video for GAJDE.Stream/Download G...
# 2  Stream or Download âAM/PMâ here ð§ https...
# 3  Bzzz Entertainment - https://lnk.to/BzzzStream...
# 4  Stream âTequilaâ:https://taynaxazet.lnk.to...

# %%
df.dtypes
# Out:
# country              object
# video_id             object
# title                object
# publishedAt          object
# channelId            object
# channelTitle         object
# categoryId            int64
# trending_date        object
# tags                 object
# view_count            int64
# comment_count         int64
# thumbnail_link       object
# comments_disabled      bool
# ratings_disabled       bool
# description          object
# dtype: object

# %%
a=pd.to_datetime(df['publishedAt'], format="%Y-%m-%d", exact=False)

df['Upload Date'] = a.dt.date.astype('datetime64')
df['Upload Time'] = a.dt.time
df.head()
# Out:
#   country     video_id                                              title  \
# 0      AL  hxWSp-8jJuo                                 DON XHONI - KATILE
# 1      AL  MnrC9mk2H1o  Dhurata Dora x Elvana Gjata - GAJDE (Official ...
# 2      AL  5Ql-G0dTqC0                       KIDA x BUTRINT IMERI - AM/PM
# 3      AL  oUdY0qSavvY                              Dafina Zeqiri - Malli
# 4      AL  I4ZSvYLnOcQ                             Tayna x Azet - Tequila
#
#             publishedAt                 channelId           channelTitle  \
# 0  2022-07-07T22:00:12Z  UCZNJXsf2I4y54M_UmMiC6Vw              DON XHONI
# 1  2022-06-30T22:00:11Z  UCtzhq8TIfFB9vRAHVqLL9PA           Dhurata Dora
# 2  2022-07-02T22:00:11Z  UCAHVxL9FG3Sp8ltQtLEy_oA                   KIDA
# 3  2022-07-07T22:00:12Z  UCrv0PJoutcRhHkSMJYoXAIQ          Dafina Zeqiri
# 4  2022-06-30T18:00:26Z  UCJBZ-GcWSswmJ0xc9WAKDqw  Friends Entertainment
#
#    categoryId trending_date  \
# 0          24      22.11.07
# 1          10      22.11.07
# 2          10      22.11.07
# 3          10      22.11.07
# 4          10      22.11.07
#
#                                                 tags  view_count  \
# 0                                             [none]     5130167
# 1                                             [none]     8886648
# 2  Butrint Imeri|Kida|Dale|Butrint imeri kida|But...     7230818
# 3  Dafina|Zeqiri|Dafine Moj|Pa ty|Lule Lule|Duro|...     1406078
# 4  tayna|Friends|Entertainment|rinor hykolli|hip ...     6397676
#
#    comment_count                                  thumbnail_link  \
# 0           3641  https://i.ytimg.com/vi/hxWSp-8jJuo/default.jpg
# 1           4414  https://i.ytimg.com/vi/MnrC9mk2H1o/default.jpg
# 2           7518  https://i.ytimg.com/vi/5Ql-G0dTqC0/default.jpg
# 3            827  https://i.ytimg.com/vi/oUdY0qSavvY/default.jpg
# 4           6063  https://i.ytimg.com/vi/I4ZSvYLnOcQ/default.jpg
#
#    comments_disabled  ratings_disabled  \
# 0              False              True
# 1              False              True
# 2              False              True
# 3              False              True
# 4              False              True
#
#                                          description Upload Date Upload Time
# 0  Stream or Download now ''KATILE'' ð https:/...  2022-07-07    22:00:12
# 1  The official video for GAJDE.Stream/Download G...  2022-06-30    22:00:11
# 2  Stream or Download âAM/PMâ here ð§ https...  2022-07-02    22:00:11
# 3  Bzzz Entertainment - https://lnk.to/BzzzStream...  2022-07-07    22:00:12
# 4  Stream âTequilaâ:https://taynaxazet.lnk.to...  2022-06-30    18:00:26

# %%
df=df.drop(columns=['publishedAt','tags','description','thumbnail_link'])
df.head()
# Out:
#   country     video_id                                              title  \
# 0      AL  hxWSp-8jJuo                                 DON XHONI - KATILE
# 1      AL  MnrC9mk2H1o  Dhurata Dora x Elvana Gjata - GAJDE (Official ...
# 2      AL  5Ql-G0dTqC0                       KIDA x BUTRINT IMERI - AM/PM
# 3      AL  oUdY0qSavvY                              Dafina Zeqiri - Malli
# 4      AL  I4ZSvYLnOcQ                             Tayna x Azet - Tequila
#
#                   channelId           channelTitle  categoryId trending_date  \
# 0  UCZNJXsf2I4y54M_UmMiC6Vw              DON XHONI          24      22.11.07
# 1  UCtzhq8TIfFB9vRAHVqLL9PA           Dhurata Dora          10      22.11.07
# 2  UCAHVxL9FG3Sp8ltQtLEy_oA                   KIDA          10      22.11.07
# 3  UCrv0PJoutcRhHkSMJYoXAIQ          Dafina Zeqiri          10      22.11.07
# 4  UCJBZ-GcWSswmJ0xc9WAKDqw  Friends Entertainment          10      22.11.07
#
#    view_count  comment_count  comments_disabled  ratings_disabled Upload Date  \
# 0     5130167           3641              False              True  2022-07-07
# 1     8886648           4414              False              True  2022-06-30
# 2     7230818           7518              False              True  2022-07-02
# 3     1406078            827              False              True  2022-07-07
# 4     6397676           6063              False              True  2022-06-30
#
#   Upload Time
# 0    22:00:12
# 1    22:00:11
# 2    22:00:11
# 3    22:00:12
# 4    18:00:26

# %%
df.dtypes
# Out:
# country                      object
# video_id                     object
# title                        object
# channelId                    object
# channelTitle                 object
# categoryId                    int64
# trending_date                object
# view_count                    int64
# comment_count                 int64
# comments_disabled              bool
# ratings_disabled               bool
# Upload Date          datetime64[ns]
# Upload Time                  object
# dtype: object

# %%
df['trending_date']=df['trending_date'].astype('str')
df['trending_date'] = '20'+df['trending_date']
df['trending_date']=pd.to_datetime(df['trending_date'],format='%Y.%m.%d')
df['trending_date'] = df['trending_date'].astype('datetime64')

df.head()
# Out:
#   country     video_id                                              title  \
# 0      AL  hxWSp-8jJuo                                 DON XHONI - KATILE
# 1      AL  MnrC9mk2H1o  Dhurata Dora x Elvana Gjata - GAJDE (Official ...
# 2      AL  5Ql-G0dTqC0                       KIDA x BUTRINT IMERI - AM/PM
# 3      AL  oUdY0qSavvY                              Dafina Zeqiri - Malli
# 4      AL  I4ZSvYLnOcQ                             Tayna x Azet - Tequila
#
#                   channelId           channelTitle  categoryId trending_date  \
# 0  UCZNJXsf2I4y54M_UmMiC6Vw              DON XHONI          24    2022-11-07
# 1  UCtzhq8TIfFB9vRAHVqLL9PA           Dhurata Dora          10    2022-11-07
# 2  UCAHVxL9FG3Sp8ltQtLEy_oA                   KIDA          10    2022-11-07
# 3  UCrv0PJoutcRhHkSMJYoXAIQ          Dafina Zeqiri          10    2022-11-07
# 4  UCJBZ-GcWSswmJ0xc9WAKDqw  Friends Entertainment          10    2022-11-07
#
#    view_count  comment_count  comments_disabled  ratings_disabled Upload Date  \
# 0     5130167           3641              False              True  2022-07-07
# 1     8886648           4414              False              True  2022-06-30
# 2     7230818           7518              False              True  2022-07-02
# 3     1406078            827              False              True  2022-07-07
# 4     6397676           6063              False              True  2022-06-30
#
#   Upload Time
# 0    22:00:12
# 1    22:00:11
# 2    22:00:11
# 3    22:00:12
# 4    18:00:26

# %%
df.columns=['Country','Video Id','Title','Channel Id','Channel Title','Category Id','Trending Date','View Count','comment count','Comments Disabled','Ratings Disabled','Upload Date','Upload Time']

# %%
df.head()
# Out:
#   Country     Video Id                                              Title  \
# 0      AL  hxWSp-8jJuo                                 DON XHONI - KATILE
# 1      AL  MnrC9mk2H1o  Dhurata Dora x Elvana Gjata - GAJDE (Official ...
# 2      AL  5Ql-G0dTqC0                       KIDA x BUTRINT IMERI - AM/PM
# 3      AL  oUdY0qSavvY                              Dafina Zeqiri - Malli
# 4      AL  I4ZSvYLnOcQ                             Tayna x Azet - Tequila
#
#                  Channel Id          Channel Title  Category Id Trending Date  \
# 0  UCZNJXsf2I4y54M_UmMiC6Vw              DON XHONI           24    2022-11-07
# 1  UCtzhq8TIfFB9vRAHVqLL9PA           Dhurata Dora           10    2022-11-07
# 2  UCAHVxL9FG3Sp8ltQtLEy_oA                   KIDA           10    2022-11-07
# 3  UCrv0PJoutcRhHkSMJYoXAIQ          Dafina Zeqiri           10    2022-11-07
# 4  UCJBZ-GcWSswmJ0xc9WAKDqw  Friends Entertainment           10    2022-11-07
#
#    View Count  comment count  Comments Disabled  Ratings Disabled Upload Date  \
# 0     5130167           3641              False              True  2022-07-07
# 1     8886648           4414              False              True  2022-06-30
# 2     7230818           7518              False              True  2022-07-02
# 3     1406078            827              False              True  2022-07-07
# 4     6397676           6063              False              True  2022-06-30
#
#   Upload Time
# 0    22:00:12
# 1    22:00:11
# 2    22:00:11
# 3    22:00:12
# 4    18:00:26
